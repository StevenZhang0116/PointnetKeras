# %%
# https://keras.io/examples/vision/pointnet/
import os
import glob
# !pip install trimesh
import trimesh
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt

tf.random.set_seed(1234)
# Out:
# Collecting trimesh
#   Downloading https://files.pythonhosted.org/packages/79/e3/a4f0bd71a88a816bd977afea62a11044e1862686fc1b0ec6d184e8b303ee/trimesh-3.8.19-py3-none-any.whl (627kB)
#      |████████████████████████████████| 634kB 13.2MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from trimesh) (50.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from trimesh) (1.19.4)
# Installing collected packages: trimesh
# Successfully installed trimesh-3.8.19

# %%
print("Start")
DATA_DIR = tf.keras.utils.get_file(
    "modelnet.zip",
    "http://3dvision.princeton.edu/projects/2014/3DShapeNets/ModelNet10.zip",
    extract=True,
)
print(DATA_DIR)
DATA_DIR = os.path.join(os.path.dirname(DATA_DIR), "ModelNet10")
print(DATA_DIR)
print("End")
# Out:
# Start
# Downloading data from http://3dvision.princeton.edu/projects/2014/3DShapeNets/ModelNet10.zip
# 473407488/473402300 [==============================] - 14s 0us/step
# /root/.keras/datasets/modelnet.zip
# /root/.keras/datasets/ModelNet10
# End

# %%
print(DATA_DIR)
mesh = trimesh.load(os.path.join(DATA_DIR, "chair/train/chair_0003.off"))
mesh.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-99a29bedf9b4> in <module>()
# ----> 1 print(DATA_DIR)
#       2 mesh = trimesh.load(os.path.join(DATA_DIR, "chair/train/chair_0003.off"))
#       3 mesh.show()
#
# NameError: name 'DATA_DIR' is not defined

# %%
points = mesh.sample(1024)

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(points[:, 0], points[:, 1], points[:, 2])
ax.set_axis_off()
plt.show()

# %%
def parse_dataset(num_points=2048):
    train_points = []
    train_labels = []
    test_points = []
    test_labels = []
    class_map = {}
    folders = glob.glob(os.path.join(DATA_DIR, "[!README]*"))

    for i, folder in enumerate(folders):
        print("processing class: {}".format(os.path.basename(folder)))
        class_map[i] = folder.split("/")[-1]
        train_files = glob.glob(os.path.join(folder, "train/*"))
        test_files = glob.glob(os.path.join(folder, "test/*"))

        for f in train_files:
            train_points.append(trimesh.load(f).sample(num_points))
            train_labels.append(i)

        for f in test_files:
            test_points.append(trimesh.load(f).sample(num_points))
            test_labels.append(i)

    return (
        np.array(train_points),
        np.array(test_points),
        np.array(train_labels),
        np.array(test_labels),
        class_map,
    )

# %%
NUM_POINTS = 2048
NUM_CLASSES = 10
BATCH_SIZE = 32

# %%
train_points, test_points, train_labels, test_labels, CLASS_MAP = parse_dataset(NUM_POINTS)
# Out:
# processing class: night_stand
# processing class: bed
# processing class: monitor
# processing class: chair
# processing class: bathtub
# processing class: dresser
# processing class: sofa
# processing class: toilet
# processing class: desk
# processing class: table

# %%
def augment(points, label):
    points += tf.random.uniform(points.shape, -0.01, 0.01, dtype=tf.float64)
    points = tf.random.shuffle(points)
    return points, label


train_dataset = tf.data.Dataset.from_tensor_slices((train_points, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_points, test_labels))

train_dataset = train_dataset.shuffle(len(train_points)).map(augment).batch(BATCH_SIZE)
test_dataset = test_dataset.shuffle(len(test_points)).batch(BATCH_SIZE)

# %%
def conv_bn(x, filters):
    x = layers.Conv1D(filters, kernel_size=1, padding="valid")(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)


def dense_bn(x, filters):
    x = layers.Dense(filters)(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)

# %%
class OrthogonalRegularizer(keras.regularizers.Regularizer):
    def __init__(self, num_features, l2reg=0.001):
        self.num_features = num_features
        self.l2reg = l2reg
        self.eye = tf.eye(num_features)

    def __call__(self, x):
        x = tf.reshape(x, (-1, self.num_features, self.num_features))
        xxt = tf.tensordot(x, x, axes=(2, 2))
        xxt = tf.reshape(xxt, (-1, self.num_features, self.num_features))
        return tf.reduce_sum(self.l2reg * tf.square(xxt - self.eye))

# %%
def tnet(inputs, num_features):

    bias = keras.initializers.Constant(np.eye(num_features).flatten())
    reg = OrthogonalRegularizer(num_features)

    x = conv_bn(inputs, 32)
    x = conv_bn(x, 64)
    x = conv_bn(x, 512)
    x = layers.GlobalMaxPooling1D()(x)
    x = dense_bn(x, 256)
    x = dense_bn(x, 128)
    x = layers.Dense(
        num_features * num_features,
        kernel_initializer="zeros",
        bias_initializer=bias,
        activity_regularizer=reg,
    )(x)
    feat_T = layers.Reshape((num_features, num_features))(x)

    return layers.Dot(axes=(2, 1))([inputs, feat_T])

# %%
inputs = keras.Input(shape=(NUM_POINTS, 3))

x = tnet(inputs, 3)
x = conv_bn(x, 32)
x = conv_bn(x, 32)
x = tnet(x, 32)
x = conv_bn(x, 32)
x = conv_bn(x, 64)
x = conv_bn(x, 512)
x = layers.GlobalMaxPooling1D()(x)
x = dense_bn(x, 256)
x = layers.Dropout(0.31)(x)
x = dense_bn(x, 128)
x = layers.Dropout(0.31)(x)

outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs, name="pointnet")
model.summary()
# Out:
# Model: "pointnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1024, 3)]    0
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 1024, 32)     128         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 1024, 32)     128         conv1d_22[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 1024, 32)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 1024, 64)     2112        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 1024, 64)     256         conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 1024, 64)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 1024, 512)    33280       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 1024, 512)    2048        conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 1024, 512)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_6 (GlobalM (None, 512)          0           activation_36[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 256)          131328      global_max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 256)          1024        dense_18[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 256)          0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 128)          32896       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128)          512         dense_19[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 128)          0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 9)            1161        activation_38[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 3, 3)         0           dense_20[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 1024, 3)      0           input_3[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 1024, 32)     128         dot_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 1024, 32)     128         conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 1024, 32)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 1024, 32)     1056        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 1024, 32)     128         conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 1024, 32)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 1024, 32)     1056        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 1024, 32)     128         conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 1024, 32)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 1024, 64)     2112        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 1024, 64)     256         conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 1024, 64)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 1024, 512)    33280       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 1024, 512)    2048        conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 1024, 512)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_7 (GlobalM (None, 512)          0           activation_43[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 256)          131328      global_max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 256)          1024        dense_21[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 256)          0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 128)          32896       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 128)          512         dense_22[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 128)          0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1024)         132096      activation_45[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 32, 32)       0           dense_23[0][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 1024, 32)     0           activation_40[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 1024, 32)     1056        dot_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 1024, 32)     128         conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 1024, 32)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 1024, 64)     2112        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 1024, 64)     256         conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 1024, 64)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 1024, 512)    33280       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 1024, 512)    2048        conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 1024, 512)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_8 (GlobalM (None, 512)          0           activation_48[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 256)          131328      global_max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 256)          1024        dense_24[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 256)          0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256)          0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 128)          32896       dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 128)          512         dense_25[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128)          0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128)          0           activation_50[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 10)           1290        dropout_5[0][0]
# ==================================================================================================
# Total params: 748,979
# Trainable params: 742,899
# Non-trainable params: 6,080
# __________________________________________________________________________________________________

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=["sparse_categorical_accuracy"],
)

model.fit(train_dataset, epochs=30, validation_data=test_dataset)

# model.save('my_model.h5')

# print("Successfully saved! ")
# Out:
# Epoch 1/30
# 125/125 [==============================] - 206s 2s/step - loss: 3.4678 - sparse_categorical_accuracy: 0.3029 - val_loss: 25139087828582400.0000 - val_sparse_categorical_accuracy: 0.3524
# Epoch 2/30
# 125/125 [==============================] - 204s 2s/step - loss: 2.8981 - sparse_categorical_accuracy: 0.4435 - val_loss: 58089020361539584.0000 - val_sparse_categorical_accuracy: 0.4802
# Epoch 3/30
# 125/125 [==============================] - 205s 2s/step - loss: 2.6964 - sparse_categorical_accuracy: 0.5034 - val_loss: 451519603906969600.0000 - val_sparse_categorical_accuracy: 0.5011
# Epoch 4/30
# 125/125 [==============================] - 203s 2s/step - loss: 2.5246 - sparse_categorical_accuracy: 0.5673 - val_loss: 30130200603787264.0000 - val_sparse_categorical_accuracy: 0.5264
# Epoch 5/30
# 125/125 [==============================] - 203s 2s/step - loss: 2.7636 - sparse_categorical_accuracy: 0.5570 - val_loss: 40860851555876732928.0000 - val_sparse_categorical_accuracy: 0.5573
# Epoch 6/30
# 125/125 [==============================] - 203s 2s/step - loss: 2.3569 - sparse_categorical_accuracy: 0.6009 - val_loss: 25665128628224.0000 - val_sparse_categorical_accuracy: 0.6476
# Epoch 7/30
# 125/125 [==============================] - 204s 2s/step - loss: 2.3330 - sparse_categorical_accuracy: 0.6104 - val_loss: 38202797795049472.0000 - val_sparse_categorical_accuracy: 0.6696
# Epoch 8/30
# 125/125 [==============================] - 206s 2s/step - loss: 2.3012 - sparse_categorical_accuracy: 0.6434 - val_loss: 40.8549 - val_sparse_categorical_accuracy: 0.3700
# Epoch 9/30
# 125/125 [==============================] - 207s 2s/step - loss: 2.2367 - sparse_categorical_accuracy: 0.6600 - val_loss: 20892.2461 - val_sparse_categorical_accuracy: 0.5881
# Epoch 10/30
# 125/125 [==============================] - 206s 2s/step - loss: 2.0274 - sparse_categorical_accuracy: 0.7116 - val_loss: 33981491838976.0000 - val_sparse_categorical_accuracy: 0.7137
# Epoch 11/30
# 125/125 [==============================] - 207s 2s/step - loss: 1.9610 - sparse_categorical_accuracy: 0.7331 - val_loss: 1304362188902760448.0000 - val_sparse_categorical_accuracy: 0.7070
# Epoch 12/30
# 125/125 [==============================] - 208s 2s/step - loss: 1.9507 - sparse_categorical_accuracy: 0.7246 - val_loss: 11891592134656.0000 - val_sparse_categorical_accuracy: 0.7214
# Epoch 13/30
# 125/125 [==============================] - 206s 2s/step - loss: 1.8586 - sparse_categorical_accuracy: 0.7597 - val_loss: 10868412595044352.0000 - val_sparse_categorical_accuracy: 0.7269
# Epoch 14/30
# 125/125 [==============================] - 205s 2s/step - loss: 1.8412 - sparse_categorical_accuracy: 0.7642 - val_loss: 131731304.0000 - val_sparse_categorical_accuracy: 0.7896
# Epoch 15/30
# 125/125 [==============================] - 208s 2s/step - loss: 1.7707 - sparse_categorical_accuracy: 0.7777 - val_loss: 51089225599030394880.0000 - val_sparse_categorical_accuracy: 0.7048
# Epoch 16/30
# 125/125 [==============================] - 205s 2s/step - loss: 1.7657 - sparse_categorical_accuracy: 0.7800 - val_loss: 688523321540608.0000 - val_sparse_categorical_accuracy: 0.7974
# Epoch 17/30
# 125/125 [==============================] - 203s 2s/step - loss: 1.7613 - sparse_categorical_accuracy: 0.7830 - val_loss: 29265043866517504.0000 - val_sparse_categorical_accuracy: 0.7324
# Epoch 18/30
# 125/125 [==============================] - 204s 2s/step - loss: 1.8665 - sparse_categorical_accuracy: 0.7702 - val_loss: 14281693972135936000.0000 - val_sparse_categorical_accuracy: 0.7126
# Epoch 19/30
# 125/125 [==============================] - 203s 2s/step - loss: 1.7880 - sparse_categorical_accuracy: 0.7780 - val_loss: 43891140.0000 - val_sparse_categorical_accuracy: 0.8315
# Epoch 20/30
# 125/125 [==============================] - 203s 2s/step - loss: 1.6741 - sparse_categorical_accuracy: 0.8128 - val_loss: 1724739354624.0000 - val_sparse_categorical_accuracy: 0.7676
# Epoch 21/30
# 125/125 [==============================] - 204s 2s/step - loss: 1.6440 - sparse_categorical_accuracy: 0.8156 - val_loss: 11.6392 - val_sparse_categorical_accuracy: 0.7786
# Epoch 22/30
# 125/125 [==============================] - 201s 2s/step - loss: 1.6674 - sparse_categorical_accuracy: 0.8126 - val_loss: 5176998422904832.0000 - val_sparse_categorical_accuracy: 0.7907
# Epoch 23/30
# 125/125 [==============================] - 201s 2s/step - loss: 1.6190 - sparse_categorical_accuracy: 0.8324 - val_loss: 3575501486555136.0000 - val_sparse_categorical_accuracy: 0.8227
# Epoch 24/30
# 125/125 [==============================] - 203s 2s/step - loss: 1.6262 - sparse_categorical_accuracy: 0.8261 - val_loss: 2378483367936.0000 - val_sparse_categorical_accuracy: 0.8282
# Epoch 25/30
# 125/125 [==============================] - 202s 2s/step - loss: 1.6574 - sparse_categorical_accuracy: 0.8181 - val_loss: 114.4999 - val_sparse_categorical_accuracy: 0.7599
# Epoch 26/30
# 125/125 [==============================] - 202s 2s/step - loss: 1.6282 - sparse_categorical_accuracy: 0.8354 - val_loss: 2.3511 - val_sparse_categorical_accuracy: 0.5947
# Epoch 27/30
# 125/125 [==============================] - 203s 2s/step - loss: 1.6014 - sparse_categorical_accuracy: 0.8379 - val_loss: 5.6147 - val_sparse_categorical_accuracy: 0.7313
# Epoch 28/30
# 125/125 [==============================] - 201s 2s/step - loss: 1.6151 - sparse_categorical_accuracy: 0.8286 - val_loss: 12.0367 - val_sparse_categorical_accuracy: 0.5628
# Epoch 29/30
# 125/125 [==============================] - 202s 2s/step - loss: 1.5386 - sparse_categorical_accuracy: 0.8609 - val_loss: 15962790166528.0000 - val_sparse_categorical_accuracy: 0.7764
# Epoch 30/30
# 125/125 [==============================] - 205s 2s/step - loss: 1.5851 - sparse_categorical_accuracy: 0.8389 - val_loss: 925991.0625 - val_sparse_categorical_accuracy: 0.8414

# %%
data = test_dataset.take(1)

points, labels = list(data)[0]
points = points[20:32, ...]
labels = labels[20:32, ...]

# run test data through model
preds = model.predict(points)
preds = tf.math.argmax(preds, -1)

points = points.numpy()

# plot points with predicted class and label
fig = plt.figure(figsize=(15, 10))
for i in range(12):
    ax = fig.add_subplot(5, 4, i + 1, projection="3d")
    ax.scatter(points[i, :, 0], points[i, :, 1], points[i, :, 2])
    ax.set_title(
        "pred: {:}, label: {:}".format(
            CLASS_MAP[preds[i].numpy()], CLASS_MAP[labels.numpy()[i]]
        )
    )
    ax.set_axis_off()
plt.show()
